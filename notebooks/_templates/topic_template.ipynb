# %% [markdown]
# <style>
# :root {
#     --dsa-prose-font: Inter, -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#     --dsa-code-font: "JetBrains Mono", "SFMono-Regular", Menlo, Monaco, Consolas, monospace;
# }
#
# .jp-RenderedHTMLCommon,
# .jp-MarkdownOutput,
# .markdown-body {
#     font-family: var(--dsa-prose-font);
#     font-size: 16px;
#     line-height: 1.7;
# }
#
# .jp-RenderedHTMLCommon h1,
# .jp-RenderedHTMLCommon h2,
# .jp-RenderedHTMLCommon h3,
# .jp-MarkdownOutput h1,
# .jp-MarkdownOutput h2,
# .jp-MarkdownOutput h3,
# .markdown-body h1,
# .markdown-body h2,
# .markdown-body h3 {
#     font-family: var(--dsa-prose-font);
#     font-weight: 700;
#     letter-spacing: -0.02em;
# }
#
# .jp-CodeCell pre,
# .jp-CodeCell code,
# .CodeMirror,
# .cm-editor,
# .markdown-body code,
# .markdown-body pre {
#     font-family: var(--dsa-code-font);
# }
# </style>
#
# # Topic Name
#
# > Status: In Progress | Last updated: YYYY-MM-DD
#
# ## Learning Goals
#
# Describe the skills you should have after completing this topic.

# %% [markdown]
# ## Core Concepts and Reusable Pattern
#
# Record definitions, prerequisites, invariants, complexity, boundary handling, and common mistakes.

# %%
# Implement the reusable pattern here.

# %% [markdown]
# ## Problem Map and My Key Questions
#
# | # | Problem | Difficulty | My Questions / Key Points | Status |
# |---:|---|:---:|---|:---:|
# | 01 | Problem Number. Problem Name | Easy | Add your own questions and key observations here. | ⬜ |

# %% [markdown]
# ---
# ## 🟣 Problem 01 — LeetCode Number: Problem Name
#
# <div style="border-left: 6px solid #7c3aed; background: #f5f3ff; padding: 12px 16px; margin: 12px 0 20px; border-radius: 6px; color: #4c1d95;">
# <strong>Pattern:</strong> Name the primary pattern &nbsp; | &nbsp; <strong>Difficulty:</strong> Easy &nbsp; | &nbsp; <strong>Status:</strong> ✅ Completed
# </div>
#
# ### Problem Summary
#
# Summarize the inputs, outputs, and constraints in your own words.
#
# ### Approach
#
# Record the key observation, invariant, boundary convention, and why the algorithm is correct.
#
# ### Complexity
#
# - Time: `O(?)`
# - Space: `O(?)`

# %%
def solution():
    pass

# %%
# Test typical, boundary, and special cases.

# %% [markdown]
# ### Review
#
# Record mistakes, easy-to-forget details, and revisit dates.
#
# <div style="text-align: center; color: #7c3aed; font-weight: 600; margin: 24px 0;">◆ END OF PROBLEM 01 ◆</div>
